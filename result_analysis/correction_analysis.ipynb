# %%
from result_analysis import show_correction_performance, show_correction_similarity, show_correction_similarity_errors, compare_noise_types, compare_correction_similarity
import pandas as pd

# %%
algorithms = ['PL', 'STC', 'CC', 'HLNC', 'OBNC', 'BE']

experiments = ['phishing_having_IP_Address', 'bank_housing', 'monks1_attr3', 'biodeg_V25', 
                'credit_A1', 'sick_referral_source_other', 'vote_immigration', 'ads_local', 'churn_voice_mail_plan']

noise_types = ['random', 'flip', 'bias', 'balanced_bias']

# %%
runs = {}
for noise_type in noise_types:
    runs[noise_type] = {}
    for exp in experiments:
        for alg in algorithms:
            runs[noise_type][f'{exp}_{alg}'] = pd.read_csv(f'../noiseinjection_results/{noise_type}/{exp}_{alg}.csv').fillna(0)

# %% [markdown]
# # Random Noise

# %%
show_correction_similarity('random', algorithms, experiments, runs)

# %%
show_correction_similarity_errors('random', algorithms, experiments, runs)

# %%
show_correction_performance('random', algorithms, experiments, runs)

# %% [markdown]
# # Label flipping

# %%
show_correction_similarity('flip', algorithms, experiments, runs)

# %%
show_correction_similarity_errors('flip', algorithms, experiments, runs)

# %%
show_correction_performance('flip', algorithms, experiments, runs)

# %% [markdown]
# # Positive Bias

# %%
show_correction_similarity('bias', algorithms, experiments, runs)

# %%
show_correction_similarity_errors('bias', algorithms, experiments, runs)

# %%
show_correction_performance('bias', algorithms, experiments, runs)

# %% [markdown]
# # Balanced Bias

# %%
show_correction_similarity('balanced_bias', algorithms, experiments, runs)

# %%
show_correction_similarity_errors('balanced_bias', algorithms, experiments, runs)

# %%
show_correction_performance('balanced_bias', algorithms, experiments, runs)

# %% [markdown]
# # Comparing noise types

# %%
compare_correction_similarity(['flip', 'bias', 'balanced_bias'], algorithms, experiments, runs)

# %%
compare_correction_similarity(noise_types, algorithms, experiments, runs)

# %%
compare_noise_types('acc', algorithms, noise_types, experiments, runs)
